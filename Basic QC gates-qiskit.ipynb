# %% [markdown]
# ------------------

# %% [markdown]
# --------------------

# %%
# To install the qiskit 
# %pip install qiskit
# Out:
# Requirement already satisfied: qiskit in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (2.2.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit) (2.3.3)
# Requirement already satisfied: scipy>=1.5 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit) (1.16.2)
# Requirement already satisfied: dill>=0.3 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit) (5.5.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# To run the jobs on real quantum computer
! pip install qiskit-ibm-runtime
# Out:
# Requirement already satisfied: qiskit-ibm-runtime in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (0.42.0)
# Requirement already satisfied: requests>=2.19 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.32.5)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: numpy>=1.13 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.3.3)
# Requirement already satisfied: urllib3>=1.21.1 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.9.0.post0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit-ibm-runtime) (0.68.3)
# Requirement already satisfied: pydantic>=2.5.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.11.9)
# Requirement already satisfied: qiskit>=1.4.1 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.2.1)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit-ibm-runtime) (25.0)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.2 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (3.24.2)
# Requirement already satisfied: PyJWT<3.0.0,>=2.10.1 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (2.10.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from python-dateutil>=2.8.0->qiskit-ibm-runtime) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from requests>=2.19->qiskit-ibm-runtime) (2025.8.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.4.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (1.16.2)
# Requirement already satisfied: dill>=0.3 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (5.5.0)
# Requirement already satisfied: cryptography>=1.3 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (46.0.1)
# Requirement already satisfied: pyspnego>=0.4.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.12.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.23)

# %%
#If you intend to use visualization functionality or Jupyter notebooks, 
#it is recommended to install Qiskit with the extra visualization support ('qiskit[visualization]').
! pip install 'qiskit[visualization]'
# Out:
# Requirement already satisfied: qiskit[visualization] in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (2.2.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit[visualization]) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit[visualization]) (2.3.3)
# Requirement already satisfied: scipy>=1.5 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit[visualization]) (1.16.2)
# Requirement already satisfied: dill>=0.3 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit[visualization]) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit[visualization]) (5.5.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit[visualization]) (4.15.0)
# Requirement already satisfied: matplotlib>=3.3 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit[visualization]) (3.10.6)
# Requirement already satisfied: pydot in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit[visualization]) (4.0.1)
# Requirement already satisfied: Pillow>=4.2.1 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit[visualization]) (11.3.0)
# Requirement already satisfied: pylatexenc>=1.4 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit[visualization]) (2.10)
# Requirement already satisfied: seaborn>=0.9.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit[visualization]) (0.13.2)
# Requirement already satisfied: sympy>=1.3 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit[visualization]) (1.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from matplotlib>=3.3->qiskit[visualization]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from matplotlib>=3.3->qiskit[visualization]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from matplotlib>=3.3->qiskit[visualization]) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from matplotlib>=3.3->qiskit[visualization]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from matplotlib>=3.3->qiskit[visualization]) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from matplotlib>=3.3->qiskit[visualization]) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from matplotlib>=3.3->qiskit[visualization]) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->qiskit[visualization]) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from seaborn>=0.9.0->qiskit[visualization]) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]) (2025.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from sympy>=1.3->qiskit[visualization]) (1.3.0)

# %% [markdown]
# ## Basics first

# %%
from qiskit import QuantumCircuit
from matplotlib import pyplot as plt

# %%
# THE HADAMARD & CNOT GATE
qc = QuantumCircuit(2)
qc.h(1)
qc.cx(1, 0)
qc.draw('mpl')

# %%
from qiskit.quantum_info import Statevector
sv = Statevector(qc)
sv.draw("latex")
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |11\rangle$$

# %%
type(qc.draw('mpl'))
# Out:
# matplotlib.figure.Figure

# %% [markdown]
# ## Reverse the qubit numbering

# %%
qc.draw('mpl', reverse_bits=True)

# %%
#rendering
qc.draw('mpl', fold = 2)

# %% [markdown]
# ## Statevector

# %%
from qiskit.quantum_info import *

# %%
sv = Statevector(qc)
sv.draw()
# Out:
# 'Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,\n             0.70710678+0.j],\n            dims=(2, 2))'

# %%
sv.draw('latex')
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |11\rangle$$

# %%
sv.draw('text')
# Out:
# [0.70710678+0.j,0.        +0.j,0.        +0.j,0.70710678+0.j]

# %% [markdown]
# ## Example

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.h(1)
qc.draw('mpl')

# %%
sv = Statevector(qc)
sv.draw('latex')
# Out:
# $$\frac{1}{2} |00\rangle+\frac{1}{2} |01\rangle+\frac{1}{2} |10\rangle+\frac{1}{2} |11\rangle$$

# %% [markdown]
# ## Probabilities in state vectors

# %%
probs = sv.probabilities()
print(probs)
# Out:
# [0.25 0.25 0.25 0.25]

# %% [markdown]
# ## Counts

# %%
counts = sv.sample_counts(shots= 1024)
print(counts)
# Out:
# {np.str_('00'): np.int64(245), np.str_('01'): np.int64(254), np.str_('10'): np.int64(245), np.str_('11'): np.int64(280)}

# %% [markdown]
# ### what is the count of '01'

# %%
print(counts['01'])

# Similarly you will get the count for 00, 10, 11
#Try it out
# Out:
# 254

# %% [markdown]
# ## Visualize the results

# %%
from qiskit.visualization import plot_histogram

# %%
plot_histogram(counts)

# %% [markdown]
# ## If you want to see every sample

# %%
samples = sv.sample_memory(shots = 100)
print(samples)
# Out:
# ['01' '01' '00' '01' '01' '01' '00' '11' '01' '00' '01' '01' '00' '10'
#  '10' '10' '11' '11' '01' '10' '10' '00' '11' '01' '11' '00' '01' '10'
#  '00' '01' '10' '11' '10' '10' '01' '00' '11' '10' '00' '10' '01' '11'
#  '00' '00' '00' '01' '01' '10' '00' '11' '11' '10' '00' '10' '11' '00'
#  '00' '10' '11' '11' '01' '00' '00' '11' '10' '10' '00' '01' '11' '10'
#  '11' '11' '11' '01' '01' '11' '10' '00' '00' '01' '11' '00' '11' '11'
#  '01' '01' '11' '10' '10' '01' '01' '00' '11' '01' '10' '00' '00' '00'
#  '00' '01']

# %% [markdown]
# ## Evolve the state

# %%
sv = Statevector(qc)
sv.draw('latex')
# Out:
# $$\frac{1}{2} |00\rangle+\frac{1}{2} |01\rangle+\frac{1}{2} |10\rangle+\frac{1}{2} |11\rangle$$

# %%
import numpy as np


var1 = 'iZZ'
p = Pauli(var1)
print(p)
op = Operator(p)
print(op)
sv.evolve(op).draw('latex')
# Out:
# iZZ
# Operator([[ 0.+1.j,  0.+0.j,  0.+0.j,  0.+0.j],
#           [ 0.+0.j, -0.-1.j,  0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j, -0.-1.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j,  0.+0.j,  0.+1.j]],
#          input_dims=(2, 2), output_dims=(2, 2))
# $$\frac{i}{2} |00\rangle- \frac{i}{2} |01\rangle- \frac{i}{2} |10\rangle+\frac{i}{2} |11\rangle$$

# %% [markdown]
# ## Creating a operator

# %%
# O =  SparsePauliOp(['ZZ','XX','II'],[0.2,-0.3,0.4])
# O.to_operator()

## Operator = 0.2* ZZ + 0.4*II

O =  SparsePauliOp(['ZZ','II'],[0.2,0.4])
O.to_operator().draw('latex')
# Out:
# $$
#
# \begin{bmatrix}
# \frac{3}{5} & 0 & 0 & 0  \\
#  0 & \frac{1}{5} & 0 & 0  \\
#  0 & 0 & \frac{1}{5} & 0  \\
#  0 & 0 & 0 & \frac{3}{5}  \\
#  \end{bmatrix}
# $$

# %%
ev = sv.evolve(O)
ev.draw('latex')
# Out:
# $$\frac{3}{10} |00\rangle+\frac{1}{10} |01\rangle+\frac{1}{10} |10\rangle+\frac{3}{10} |11\rangle$$

# %%
sv.draw('latex')
# Out:
# $$\frac{1}{2} |00\rangle+\frac{1}{2} |01\rangle+\frac{1}{2} |10\rangle+\frac{1}{2} |11\rangle$$

# %%
ev.draw('latex')
# Out:
# $$\frac{3}{10} |00\rangle+\frac{1}{10} |01\rangle+\frac{1}{10} |10\rangle+\frac{3}{10} |11\rangle$$

# %%
O_exp= sv.expectation_value(O)
print(O_exp)
# Out:
# (0.39999999999999986+0j)

# %%
qc1 = QuantumCircuit(1)
# qc1.x(0)
sv1 = Statevector(qc1)
sv1.draw('bloch')

# %% [markdown]
# ## Density matrix

# %%
density_mat = DensityMatrix(qc1)
density_mat.draw('latex')
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 0  \\
#  0 & 0  \\
#  \end{bmatrix}
# $$

# %%
density_mat.draw('city')

# %%
Operator(sv1).draw('latex')
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 0  \\
#  0 & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ## Measurement

# %%
from qiskit import *

# Another way to define the quantum register 
data1 = QuantumRegister(2, 'd1')
data2 = QuantumRegister(2, 'd2')
classical_data = ClassicalRegister(2,'classical')

# Lot of things going on ...PAY ATTENTION!!!!!!!!

qc1 = QuantumCircuit(data1, data2, classical_data)
qc1.h(1)
qc1.measure(data1[1],classical_data[0])
qc1.draw('mpl') # FIGURE IS IMPORTRANT

# %% [markdown]
# ## Simulate circuit using Basic Simulator
#     BasicSimulator

# %%
from qiskit import QuantumCircuit
from qiskit.providers.basic_provider import BasicSimulator

# %%
qc1 = QuantumCircuit(2,2)
qc1.h(1)
qc1.measure([0,1],[0,1]) # arugemts will be quantum specifier then classical specifier

# qc1.measure(0,0)
qc1.draw('mpl')

# %%
# first we need the simulator
simulator_basic = BasicSimulator()

# now run the cirucit using that simulator 
# shots is the number of times we want to run the circuit

job = simulator_basic.run(qc1,shots = 1024)

#Once we have the job , we can get the result 
result = job.result()
print(result)
# Out:
# Result(backend_name='basic_simulator', backend_version='0.1', job_id='79764b36-8e4b-4a11-97ea-31446e6e88f0', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0': 538, '0x2': 486}, memory=['0x0', '0x0', '0x2', '0x2', '0x2', '0x2', '0x2', '0x2', '0x0', '0x2', '0x2', '0x0', '0x0', '0x2', '0x0', '0x2', '0x2', '0x2', '0x2', '0x2', '0x0', '0x2', '0x2', '0x0', '0x0', '0x2', '0x2', '0x0', '0x0', '0x0', '0x0', '0x2', '0x2', '0x2', '0x2', '0x0', '0x0', '0x2', '0x0', '0x0', '0x0', '0x2', '0x0', '0x2', '0x2', '0x0', '0x0', '0x2', '0x0', '0x2', '0x0', '0x2', '0x2', '0x0', '0x0', '0x0', '0x2', '0x2', '0x0', '0x2', '0x0', '0x2', '0x0', '0x2', '0x2', '0x2', '0x2', '0x2', '0x2', '0x0', '0x2', '0x2', '0x2', '0x2', '0x2', '0x0', '0x0', '0x0', '0x2', '0x0', '0x0', '0x0', '0x2', '0x0', '0x2', '0x2', '0x0', '0x2', '0x0', '0x0', '0x2', '0x0', '0x2', '0x2', '0x2', '0x2', '0x0', '0x2', '0x2', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x2', '0x2', '0x0', '0x2', '0x0', '0x2', '0x0', '0x2', '0x0', '0x0', '0x2', '0x2', '0x2', '0x0', '0x0', '0x0', '0x2', '0x2', '0x0', '0x2', '0x0', '0x0', '0x0', '0x0', '0x0', '0x2', '0x0', '0x0', '0x2', '0x2', '0x2', '0x0', '0x0', '0x0', '0x2', '0x0', '0x0', '0x0', '0x2', '0x2', '0x0', '0x2', '0x0', '0x2', '0x0', '0x0', '0x2', '0x2', '0x2', '0x0', '0x2', '0x2', '0x0', '0x0', '0x0', '0x0', '0x2', '0x2', '0x0', '0x0', '0x0', '0x2', '0x2', '0x0', '0x0', '0x0', '0x2', '0x0', '0x0', '0x0', '0x0', '0x0', '0x2', '0x2', '0x2', '0x2', '0x0', '0x0', '0x2', '0x2', '0x0', '0x0', '0x0', '0x0', '0x0', '0x2', '0x0', '0x2', '0x0', '0x0', '0x0', '0x0', '0x2', '0x0', '0x0', '0x2', '0x2', '0x2', '0x0', '0x0', '0x2', '0x2', '0x0', '0x2', '0x0', '0x2', '0x2', '0x0', '0x2', '0x2', '0x2', '0x2', '0x0', '0x0', '0x2', '0x0', '0x0', '0x0', '0x2', '0x2', '0x0', '0x2', '0x2', '0x2', '0x0', '0x0', '0x2', '0x0', '0x2', '0x2', '0x2', '0x2', '0x0', '0x2', '0x2', '0x2', '0x0', '0x2', '0x2', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x2', '0x0', '0x0', '0x0', '0x2', '0x2', '0x0', '0x2', '0x0', '0x2', '0x0', '0x2', '0x2', '0x2', '0x0', '0x2', '0x2', '0x2', '0x2', '0x0', '0x0', '0x0', '0x0', '0x0', '0x2', '0x0', '0x0', '0x0', '0x0', '0x2', '0x0', '0x2', '0x0', '0x2', '0x0', '0x2', '0x2', '0x2', '0x0', '0x2', '0x2', '0x2', '0x0', '0x0', '0x2', '0x2', '0x2', '0x2', '0x2', '0x2', '0x2', '0x0', '0x2', '0x2', '0x2', '0x2', '0x2', '0x2', '0x2', '0x2', '0x2', '0x0', '0x0', '0x0', '0x0', '0x0', '0x2', '0x0', '0x2', '0x0', '0x0', '0x2', '0x2', '0x0', '0x0', '0x0', '0x0', '0x2', '0x0', '0x0', '0x2', '0x0', '0x2', '0x2', '0x0', '0x0', '0x2', '0x2', '0x0', '0x2', '0x0', '0x2', '0x0', '0x0', '0x0', '0x0', '0x0', '0x2', '0x2', '0x2', '0x0', '0x0', '0x2', '0x0', '0x2', '0x0', '0x2', '0x0', '0x2', '0x0', '0x2', '0x0', '0x2', '0x2', '0x2', '0x0', '0x0', '0x2', '0x2', '0x0', '0x0', '0x2', '0x2', '0x0', '0x2', '0x0', '0x2', '0x0', '0x0', '0x0', '0x2', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x2', '0x0', '0x2', '0x0', '0x0', '0x0', '0x2', '0x0', '0x2', '0x2', '0x0', '0x0', '0x0', '0x2', '0x0', '0x0', '0x2', '0x0', '0x0', '0x2', '0x0', '0x0', '0x2', '0x2', '0x0', '0x0', '0x2', '0x0', '0x2', '0x0', '0x2', '0x0', '0x0', '0x0', '0x0', '0x2', '0x0', '0x2', '0x0', '0x0', '0x2', '0x2', '0x0', '0x0', '0x0', '0x2', '0x0', '0x0', '0x2', '0x0', '0x2', '0x0', '0x0', '0x0', '0x2', '0x2', '0x0', '0x0', '0x2', '0x2', '0x2', '0x0', '0x0', '0x0', '0x0', '0x2', '0x2', '0x2', '0x2', '0x2', '0x2', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x2', '0x0', '0x0', '0x0', '0x2', '0x2', '0x0', '0x0', '0x2', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x2', '0x2', '0x2', '0x2', '0x2', '0x0', '0x0', '0x0', '0x2', '0x0', '0x2', '0x2', '0x0', '0x2', '0x2', '0x2', '0x0', '0x2', '0x2', '0x0', '0x2', '0x0', '0x2', '0x2', '0x0', '0x0', '0x0', '0x0', '0x2', '0x0', '0x0', '0x0', '0x2', '0x0', '0x0', '0x2', '0x0', '0x0', '0x0', '0x0', '0x0', '0x2', '0x2', '0x2', '0x0', '0x0', '0x2', '0x0', '0x2', ...

# %%
# Now fetch the important info according to our need. 

counts = result.get_counts() 
print(counts)

# Rememeber the order of the bits in the result is right to left. 
# So 01 means 1 in the first qubit and 0 in the second qubit.
# Out:
# {'00': 538, '10': 486}

# %%
from qiskit.visualization import plot_histogram
plot_histogram(counts)

# %% [markdown]
# #### Sample memory method

# %%
job = simulator_basic.run(qc1, shots = 10, memory = True)
result = job.result()
samples = result.get_memory()
print(samples)
# Out:
# ['00', '10', '00', '00', '00', '00', '00', '10', '10', '10']

# %% [markdown]
# ## Limitations of Basic_simulator

# %%
from qiskit.circuit.library import QFT
qc = QuantumCircuit(3,3)
qc.append(QFT(3),range(3))
qc.measure(range(3),range(3))
qc.draw('mpl')
# Out:
# /var/folders/1l/g3s1ytv57hv98hl39w041lxm0000gp/T/ipykernel_65565/144873715.py:3: DeprecationWarning: The class ``qiskit.circuit.library.basis_change.qft.QFT`` is deprecated as of Qiskit 2.1. It will be removed in Qiskit 3.0. ('Use qiskit.circuit.library.QFTGate or qiskit.synthesis.qft.synth_qft_full instead, for access to all previous arguments.',)
#   qc.append(QFT(3),range(3))

# %%
job = simulator_basic.run(qc, shots = 10, )
# Out:
# ---------------------------------------------------------------------------
# BasicProviderError                        Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 job = simulator_basic.run(qc, shots = 10, )
#
# File /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages/qiskit/providers/basic_provider/basic_simulator.py:469, in BasicSimulator.run(self, run_input, **run_options)
#     467 self._set_run_options(run_options=run_options)
#     468 job_id = str(uuid.uuid4())
# --> 469 job = BasicProviderJob(self, job_id, self._run_job(job_id, run_input))
#     470 return job
#
# File /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages/qiskit/providers/basic_provider/basic_simulator.py:489, in BasicSimulator._run_job(self, job_id, run_input)
#     487 start = time.time()
#     488 for circuit in run_input:
# --> 489     result_list.append(self._run_circuit(circuit))
#     490 end = time.time()
#     491 result = {
#     492     "backend_name": self.name,
#     493     "backend_version": self.backend_version,
#    (...)    498     "time_taken": (end - start),
#     499 }
#
# File /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages/qiskit/providers/basic_provider/basic_simulator.py:631, in BasicSimulator._run_circuit(self, circuit)
#     629         backend = self.name
#     630         err_msg = '{0} encountered unrecognized operation "{1}"'
# --> 631         raise BasicProviderError(err_msg.format(backend, operation.name))
#     633 # Add final creg data to memory list
#     634 if self._number_of_cmembits > 0:
#
# BasicProviderError: 'basic_simulator encountered unrecognized operation "QFT"'

# %% [markdown]
# ### basic_simulator encountered unrecognized operation "QFT"'
# Above error is because of "QFT is not the part of basic gates that simulator can run".
#
# For this we need to transpile the the circuit : which means taking a certain type of circuit translating into gate

# %%
from qiskit import transpile

qc_t = transpile(qc, backend = simulator_basic)
job = simulator_basic.run(qc_t,shots= 1024)
result = job._result
counts = result.get_counts()
print(counts)
# Out:
# {'111': 135, '001': 125, '010': 140, '000': 129, '100': 126, '110': 125, '011': 117, '101': 127}

# %% [markdown]
# ## Qiskit_Aer

# %% [markdown]
# ### Instal the package

# %%
! pip install qiskit_aer
# Out:
# Requirement already satisfied: qiskit_aer in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (0.17.2)
# Requirement already satisfied: qiskit>=1.1.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit_aer) (2.2.1)
# Requirement already satisfied: numpy>=1.16.3 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit_aer) (2.3.3)
# Requirement already satisfied: scipy>=1.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit_aer) (1.16.2)
# Requirement already satisfied: psutil>=5 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit_aer) (7.1.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit_aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from python-dateutil>=2.8.0->qiskit_aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit>=1.1.0->qiskit_aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit>=1.1.0->qiskit_aer) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit>=1.1.0->qiskit_aer) (5.5.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/qiskit/lib/python3.13/site-packages (from qiskit>=1.1.0->qiskit_aer) (4.15.0)

# %%
qc = QuantumCircuit(2)

# Apply a Hadamard gate on the first qubit
qc.h(0)

# Apply a CNOT gate with the first qubit as control and the second as target
qc.cx(0, 1)

qc.measure_all()
# Display the circuit
qc.draw('mpl')

# %%
from qiskit_aer import Aer

simulator = Aer.get_backend('aer_simulator')

# %%
circuit = transpile(qc, simulator, optimization_level=3)
job = simulator.run(circuit, shots=256)
result = job.result()

# %%
counts = result.get_counts()
counts
plot_histogram(counts)

# %%
q = max(counts, key = counts.get)
counts[q]
# Out:
# 153

# %% [markdown]
# -------------

# %% [markdown]
# ## Conditions

# %%
qc = QuantumCircuit(2,1)
qc.h(1)
qc.measure(1,0)
with qc.if_test((qc.clbits[0], 1)):
    qc.x(0)



qc.draw('mpl')

# %% [markdown]
# ## Teleportation

# %%
#create Alice & Bob bits which is a bell state ∣Φ+⟩= 1/2(∣00⟩+∣11⟩
# Create a quantum circuit with 2 qubits and 2 classical bits
qc = QuantumCircuit(2, 2)

# Step 1: Apply Hadamard gate to qubit 0
qc.h(0)

# Step 2: Apply CNOT gate (control=0, target=1)
qc.cx(0, 1)

# Optional: Measure the qubits
qc.measure_all()

# Draw the circuit
qc.draw('mpl')

# %%
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
from qiskit.quantum_info import Statevector
import matplotlib.pyplot as plt

# Create a quantum circuit with 3 qubits and 3 classical bits
qc = QuantumCircuit(3, 3)

# Step 1: Prepare the quantum state to be teleported on qubit 0
qc.h(0)  # |+> state as an example of unknown state
qc.barrier()

# Step 2: Create entanglement (Bell pair) between qubit 1 and 2
# case 1: |Φ+⟩= 1/2(∣00⟩+∣11⟩
#qc.h(1)
#qc.cx(1, 2)
# case 2: |Φ−⟩= 1/2(∣00⟩−∣11⟩
# qc.h(1)
# case 3: |Ψ+⟩= 1/2(∣01⟩+∣10⟩
# qc.x(1)
# case 4: |Ψ−⟩= 1/2(∣01⟩−∣10⟩
qc.cx(1, 2)
qc.h(1)
qc.barrier()
qc.draw('mpl')

# %%
# Step 3: Alice's Bell measurement on qubit 0 and 1
qc.cx(0, 1)
qc.h(0)
qc.barrier()

# Draw the circuit
qc.draw('mpl')

# %%
# Step 4: Alice measures qubit 0 and 1
qc.measure(0, 0)
qc.measure(1, 1)
qc.barrier()

qc.draw('mpl')

# %%
# Step 5: Bob applies corrections based on classical bits

with qc.if_test((qc.clbits[0], 1)): # Apply Z if bit 0 is 1
    qc.z(2)
    
with qc.if_test((qc.clbits[1], 1)):  # Apply X if bit 1 is 1
    qc.x(2)
    
# Draw the circuit
qc.draw('mpl')

# %%
# Step 6: Optional - measure Bob's qubit
qc.measure(2, 2)

# # Draw the circuit
qc.draw('mpl')
